# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
five_second_data = pd.read_csv("./dataset_5secondWindow/dataset_5secondWindow.csv")
half_second_data = pd.read_csv("./dataset_halfSecondWindow/dataset_halfSecondWindow.csv")

# %%
five_second_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5893 entries, 0 to 5892
# Data columns (total 71 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Unnamed: 0                                       5893 non-null   int64
#  1   id                                               5893 non-null   int64
#  2   time                                             5893 non-null   float64
#  3   activityrecognition#0                            0 non-null      float64
#  4   activityrecognition#1                            5893 non-null   float64
#  5   android.sensor.accelerometer#mean                5893 non-null   float64
#  6   android.sensor.accelerometer#min                 5893 non-null   float64
#  7   android.sensor.accelerometer#max                 5893 non-null   float64
#  8   android.sensor.accelerometer#std                 5893 non-null   float64
# ...

# %%
half_second_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62585 entries, 0 to 62584
# Data columns (total 71 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Unnamed: 0                                       62585 non-null  int64
#  1   id                                               62585 non-null  int64
#  2   time                                             62585 non-null  float64
#  3   activityrecognition#0                            0 non-null      float64
#  4   activityrecognition#1                            62585 non-null  float64
#  5   android.sensor.accelerometer#mean                62585 non-null  float64
#  6   android.sensor.accelerometer#min                 62585 non-null  float64
#  7   android.sensor.accelerometer#max                 62585 non-null  float64
#  8   android.sensor.accelerometer#std                 62583 non-null  float64
# ...

# %%
five_second_data.describe()
# Out:
#        Unnamed: 0            id         time  activityrecognition#0  \
# count   5893.0000   5893.000000  5893.000000                    0.0
# mean    2946.0000  10685.407263   117.731716                    NaN
# std     1701.3069   6921.229833   126.474151                    NaN
# min        0.0000      0.000000     3.000000                    NaN
# 25%     1473.0000   4502.000000    31.000000                    NaN
# 50%     2946.0000  10959.000000    70.000000                    NaN
# 75%     4419.0000  17049.000000   152.000000                    NaN
# max     5892.0000  22045.000000   682.000000                    NaN
#
#        activityrecognition#1  android.sensor.accelerometer#mean  \
# count            5893.000000                        5893.000000
# mean               87.718310                          10.007976
# std                24.562728                           0.655949
# min                 3.000000                           7.369055
# ...

# %%
five_second_data.head()
# Out:
#    Unnamed: 0     id   time  activityrecognition#0  activityrecognition#1  \
# 0           0  16170   78.0                    NaN                  100.0
# 1           1  15871  145.0                    NaN                  100.0
# 2           2  16811  150.0                    NaN                  100.0
# 3           3  15831  105.0                    NaN                   77.0
# 4           4    876   77.0                    NaN                  100.0
#
#    android.sensor.accelerometer#mean  android.sensor.accelerometer#min  \
# 0                           9.811476                          9.758895
# 1                           9.939207                          7.707437
# 2                           9.827178                          9.804817
# 3                           9.673039                          7.659674
# 4                           9.993466                          8.965621
#
#    android.sensor.accelerometer#max  android.sensor.accelerometer#std  \
# ...

# %%
five_second_data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'time', 'activityrecognition#0',
#        'activityrecognition#1', 'android.sensor.accelerometer#mean',
#        'android.sensor.accelerometer#min', 'android.sensor.accelerometer#max',
#        'android.sensor.accelerometer#std',
#        'android.sensor.game_rotation_vector#mean',
#        'android.sensor.game_rotation_vector#min',
#        'android.sensor.game_rotation_vector#max',
#        'android.sensor.game_rotation_vector#std',
#        'android.sensor.gravity#mean', 'android.sensor.gravity#min',
#        'android.sensor.gravity#max', 'android.sensor.gravity#std',
#        'android.sensor.gyroscope#mean', 'android.sensor.gyroscope#min',
#        'android.sensor.gyroscope#max', 'android.sensor.gyroscope#std',
#        'android.sensor.gyroscope_uncalibrated#mean',
#        'android.sensor.gyroscope_uncalibrated#min',
#        'android.sensor.gyroscope_uncalibrated#max',
#        'android.sensor.gyroscope_uncalibrated#std',
# ...

# %%
five_second_data.isnull().sum()
# Out:
# Unnamed: 0                  0
# id                          0
# time                        0
# activityrecognition#0    5893
# activityrecognition#1       0
#                          ...
# speed#min                2373
# speed#max                2373
# speed#std                4575
# target                      0
# user                        0
# Length: 71, dtype: int64

# %%
nan_columns = five_second_data.columns[five_second_data.isnull().any()].to_list()
len(nan_columns)
# Out:
# 61

# %%
not_null_col = [col for col in five_second_data.columns if five_second_data[col].isnull().sum()<800]
len(not_null_col)
# Out:
# 44

# %%
new_data = pd.DataFrame(five_second_data[not_null_col])
new_data.head()
# Out:
#    Unnamed: 0     id   time  activityrecognition#1  \
# 0           0  16170   78.0                  100.0
# 1           1  15871  145.0                  100.0
# 2           2  16811  150.0                  100.0
# 3           3  15831  105.0                   77.0
# 4           4    876   77.0                  100.0
#
#    android.sensor.accelerometer#mean  android.sensor.accelerometer#min  \
# 0                           9.811476                          9.758895
# 1                           9.939207                          7.707437
# 2                           9.827178                          9.804817
# 3                           9.673039                          7.659674
# 4                           9.993466                          8.965621
#
#    android.sensor.accelerometer#max  android.sensor.accelerometer#std  \
# 0                          9.849411                          0.014626
# 1                         17.146631                          1.775944
# ...

# %%
not_null = [col for col in new_data.columns if new_data[col].isnull().sum() < 1]
len(not_null)
# Out:
# 10

# %%
not_null_data = new_data[not_null]

# %%
  
len(new__null)
# Out:
# 34

# %%
null_data = new_data[new__null].rolling(window=10, min_periods=1).mean()

# %%
final_data = pd.concat([not_null_data, null_data], axis=1)

# %%
final_data.head()
# Out:
#    Unnamed: 0     id   time  activityrecognition#1  \
# 0           0  16170   78.0                  100.0
# 1           1  15871  145.0                  100.0
# 2           2  16811  150.0                  100.0
# 3           3  15831  105.0                   77.0
# 4           4    876   77.0                  100.0
#
#    android.sensor.accelerometer#mean  android.sensor.accelerometer#min  \
# 0                           9.811476                          9.758895
# 1                           9.939207                          7.707437
# 2                           9.827178                          9.804817
# 3                           9.673039                          7.659674
# 4                           9.993466                          8.965621
#
#    android.sensor.accelerometer#max  android.sensor.accelerometer#std target  \
# 0                          9.849411                          0.014626  Still
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
target_num = final_data['target'].unique()
target_num
# Out:
# array(['Still', 'Car', 'Train', 'Bus', 'Walking'], dtype=object)

# %%
user_num = final_data['user'].unique()

# %%
oe = OrdinalEncoder(categories=[target_num, user_num])
oe.fit(final_data[['target','user']])
# Out:
# OrdinalEncoder(categories=[array(['Still', 'Car', 'Train', 'Bus', 'Walking'], dtype=object),
#                            array(['U12', 'U1', 'U8', 'U7', 'U10', 'U13', 'U6', 'U11', 'U3', 'U2',
#        'U4', 'U9', 'U5'], dtype=object)])

# %%
new_target = oe.transform(final_data[['target','user']])
new_target_data = pd.DataFrame(new_target, columns=['target', 'user'])

# %%
final_data.head()
# Out:
#    Unnamed: 0     id   time  activityrecognition#1  \
# 0           0  16170   78.0                  100.0
# 1           1  15871  145.0                  100.0
# 2           2  16811  150.0                  100.0
# 3           3  15831  105.0                   77.0
# 4           4    876   77.0                  100.0
#
#    android.sensor.accelerometer#mean  android.sensor.accelerometer#min  \
# 0                           9.811476                          9.758895
# 1                           9.939207                          7.707437
# 2                           9.827178                          9.804817
# 3                           9.673039                          7.659674
# 4                           9.993466                          8.965621
#
#    android.sensor.accelerometer#max  android.sensor.accelerometer#std target  \
# 0                          9.849411                          0.014626  Still
# ...

# %%
x = final_data.drop(['target',  'Unnamed: 0'], axis=1)
y = new_target_data.iloc[:,0]

# %%
data = pd.concat([x,y], axis=1)

# %%
data.head()
# Out:
#       id   time  activityrecognition#1  android.sensor.accelerometer#mean  \
# 0  16170   78.0                  100.0                           9.811476
# 1  15871  145.0                  100.0                           9.939207
# 2  16811  150.0                  100.0                           9.827178
# 3  15831  105.0                   77.0                           9.673039
# 4    876   77.0                  100.0                           9.993466
#
#    android.sensor.accelerometer#min  android.sensor.accelerometer#max  \
# 0                          9.758895                          9.849411
# 1                          7.707437                         17.146631
# 2                          9.804817                          9.849262
# 3                          7.659674                         12.304298
# 4                          8.965621                         10.891645
#
#    android.sensor.accelerometer#std user  \
# 0                          0.014626  U12
# ...

# %%
data['target'].value_counts()
# Out:
# 1.0    1180
# 0.0    1179
# 2.0    1179
# 3.0    1178
# 4.0    1177
# Name: target, dtype: int64

# %%
data['user']
# Out:
# 0       U12
# 1       U12
# 2       U12
# 3       U12
# 4        U1
#        ...
# 5888     U2
# 5889     U3
# 5890    U12
# 5891    U10
# 5892     U1
# Name: user, Length: 5893, dtype: object

# %%
x.shape
# Out:
# (5893, 42)

# %%
y.shape
# Out:
# (5893,)

# %%
from sklearn.tree import ExtraTreeClassifier
extra_tree = ExtraTreeClassifier()

# %%
extra_tree.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\asus\Documents\GitHub\Build_week_2\data_prep.ipynb Cell 31' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/asus/Documents/GitHub/Build_week_2/data_prep.ipynb#ch0000029?line=0'>1</a> extra_tree.fit(x,y)
#
# File c:\Users\asus\anaconda3\envs\school\lib\site-packages\sklearn\tree\_classes.py:903, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     <a href='file:///c%3A/Users/asus/anaconda3/envs/school/lib/site-packages/sklearn/tree/_classes.py?line=865'>866</a> def fit(self, X, y, sample_weight=None, check_input=True,
#     <a href='file:///c%3A/Users/asus/anaconda3/envs/school/lib/site-packages/sklearn/tree/_classes.py?line=866'>867</a>         X_idx_sorted="deprecated"):
# ...

# %%
extra_tree.feature_importances_
# Out:
# array([0.19767035, 0.04487217, 0.04039931, 0.0442617 , 0.12251367,
#        0.03896788, 0.10614298, 0.01164901, 0.01506403, 0.01512136,
#        0.01171774, 0.00786116, 0.00924251, 0.01319538, 0.01301808,
#        0.01278885, 0.01051294, 0.01174753, 0.01211708, 0.01272848,
#        0.01133082, 0.01080262, 0.01078273, 0.01097681, 0.01066974,
#        0.01101881, 0.0158089 , 0.01444371, 0.01456962, 0.01040821,
#        0.01046795, 0.01184822, 0.01180247, 0.0112569 , 0.0127126 ,
#        0.01232951, 0.01225956, 0.01076573, 0.01278927, 0.00940983,
#        0.01195374])

# %%
importance_feat = pd.Series(extra_tree.feature_importances_, index=x.columns)
plt.figure(figsize=(16,12))
importance_feat.nlargest(40).plot(kind = 'barh')
plt.show()

# %%
data['user']
# Out:
# 0       U12
# 1       U12
# 2       U12
# 3       U12
# 4        U1
#        ...
# 5888     U2
# 5889     U3
# 5890    U12
# 5891    U10
# 5892     U1
# Name: user, Length: 5893, dtype: object

# %%
data.to_csv('fine1_dataset.csv')
