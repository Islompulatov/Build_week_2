# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.svm import SVC

from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier,RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
import time

# %%
df = pd.read_csv('train_data.csv')

# %%
data=df.drop(['Unnamed: 0.1', 'Unnamed: 0', 'user'], axis=1)

# %%
data
# Out:
#          id   time  activityrecognition#1  android.sensor.accelerometer#mean  \
# 0     16170   78.0                  100.0                           9.811476
# 1     15871  145.0                  100.0                           9.939207
# 2     16811  150.0                  100.0                           9.827178
# 3     15831  105.0                   77.0                           9.673039
# 4     13480  559.0                  100.0                           9.330482
# ...     ...    ...                    ...                                ...
# 3418  18728  158.0                  100.0                           9.608833
# 3419  14125    4.0                  100.0                          10.066610
# 3420  19582   32.0                   10.0                           9.964271
# 3421  16178   86.0                  100.0                           9.812893
# 3422  10973  199.0                  100.0                           9.831144
#
#       android.sensor.accelerometer#min  android.sensor.accelerometer#max  \
# 0                             9.758895                          9.849411
# 1                             7.707437                         17.146631
# 2                             9.804817                          9.849262
# 3                             7.659674                         12.304298
# 4                             9.149029                          9.520044
# ...                                ...                               ...
# 3418                          9.218854                         10.113405
# 3419                          4.564648                         13.414389
# 3420                          8.768007                         11.454213
# 3421                          9.772881                          9.862587
# 3422                          9.807347                          9.874450
#
#       android.sensor.accelerometer#std  \
# 0                             0.014626
# 1                             1.775944
# 2                             0.011199
# 3                             0.862553
# 4                             0.103857
# ...                                ...
# 3418                          0.253208
# 3419                          3.373972
# 3420                          0.665529
# 3421                          0.017633
# 3422                          0.013485
#
#       android.sensor.game_rotation_vector#mean  \
# 0                                     0.029340
# 1                                     0.514633
# 2                                     0.564827
# 3                                     0.672675
# 4                                     0.650899
# ...                                        ...
# 3418                                  0.651508
# 3419                                  0.700497
# 3420                                  0.694731
# 3421                                  0.644654
# 3422                                  0.628310
#
#       android.sensor.game_rotation_vector#min  \
# 0                                    0.029014
# 1                                    0.514459
# 2                                    0.564710
# 3                                    0.671978
# 4                                    0.641942
# ...                                       ...
# 3418                                 0.650167
# 3419                                 0.697720
# 3420                                 0.692233
# 3421                                 0.642338
# 3422                                 0.626225
#
#       android.sensor.game_rotation_vector#max  ...  \
# 0                                    0.029526  ...
# 1                                    0.514736  ...
# 2                                    0.564897  ...
# 3                                    0.673338  ...
# 4                                    0.673203  ...
# ...                                       ...  ...
# 3418                                 0.652699  ...
# 3419                                 0.702374  ...
# 3420                                 0.696440  ...
# 3421                                 0.646239  ...
# 3422                                 0.629737  ...
#
#       android.sensor.magnetic_field_uncalibrated#max  \
# 0                                          51.539208
# 1                                          67.332419
# 2                                          63.511115
# 3                                          71.589169
# 4                                          88.883841
# ...                                              ...
# 3418                                      111.606884
# 3419                                      112.826388
# 3420                                      109.748124
# 3421                                       98.147247
# 3422                                      115.398709
#
#       android.sensor.orientation#mean  android.sensor.orientation#min  \
# 0                          354.286933                      353.598335
# 1                          343.491255                      342.029694
# 2                          253.911721                      252.427627
# 3                          283.822801                      279.295033
# 4                          265.698532                      230.609021
# ...                               ...                             ...
# 3418                       174.079494                      170.236641
# 3419                       181.502550                      178.128971
# 3420                       167.447707                      166.493383
# 3421                       168.334651                      167.346792
# 3422                       154.425529                      153.437636
#
#       android.sensor.orientation#max  android.sensor.orientation#std  \
# 0                         354.942707                        0.245676
# 1                         347.025657                        0.975746
# 2                         256.439963                        0.788399
# 3                         291.597908                        2.808802
# 4                         305.390420                       38.592932
# ...                              ...                             ...
# 3418                      180.826995                        4.882232
# 3419                      188.065008                        4.812927
# 3420                      168.232708                        2.297591
# 3421                      169.043590                        2.252304
# 3422                      155.134495                        0.970852
#
#       android.sensor.rotation_vector#mean  android.sensor.rotation_vector#min  \
# 0                                0.050413                            0.044777
# 1                                0.525197                            0.522370
# 2                                0.553617                            0.551732
# 3                                0.664741                            0.663327
# 4                                0.596241                            0.592273
# ...                                   ...                                 ...
# 3418                             0.794573                            0.788827
# 3419                             0.800210                            0.793717
# 3420                             0.726411                            0.718546
# 3421                             0.696535                            0.688940
# 3422                             0.654516                            0.647680
#
#       android.sensor.rotation_vector#max  android.sensor.rotation_vector#std  \
# 0                               0.056351                            0.002109
# 1                               0.528175                            0.001067
# 2                               0.555602                            0.004482
# 3                               0.666230                            0.004059
# 4                               0.608622                            0.008369
# ...                                  ...                                 ...
# 3418                            0.798741                            0.004237
# 3419                            0.804610                            0.004835
# 3420                            0.732438                            0.005022
# 3421                            0.702960                            0.004719
# 3422                            0.660299                            0.004248
#
#       target
# 0        0.0
# 1        1.0
# 2        0.0
# 3        1.0
# 4        1.0
# ...      ...
# 3418     2.0
# 3419     4.0
# 3420     2.0
# 3421     0.0
# 3422     0.0
#
# [3423 rows x 42 columns]

# %%
y = data['target']
x = data.drop(['target'], axis=1)

# %%
y.value_counts()
# Out:
# 0.0    829
# 1.0    761
# 4.0    719
# 3.0    559
# 2.0    555
# Name: target, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
tree_classifiers = {  "SVC": SVC(),
                    "Extra Trees":   ExtraTreesClassifier(),
                    "Random Forest": RandomForestClassifier(),
                    "AdaBoost":      AdaBoostClassifier(),
                    "Skl GBM":       GradientBoostingClassifier(),
                    "Logistic_reg":  LogisticRegression(),
                    "LightGBM":      KNeighborsClassifier(),
                    
                   
                    }

# %%
results = pd.DataFrame({'Model': [], 'AC':[], 'MSE': [], 'MAB': [], 'Time': []})

for model_name, model in tree_classifiers.items():
    start_time = time.time()
    model.fit(x_train,y_train)
    total_time = time.time()-start_time
    pred = model.predict(x_test)
    results = results.append({"Model":    model_name,
                            "AC": metrics.accuracy_score(y_test, pred)*100,
                            "MSE": metrics.mean_squared_error(y_test, pred),
                            "MAB": metrics.mean_absolute_error(y_test, pred),
                            "Time":     total_time},
                            ignore_index=True)

results_ord = results.sort_values(by=['MSE'], ascending=True, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['MSE', 'MAB'], vmin=0, vmax=100, color='#5fba7d')
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_25216\2965122937.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model":    model_name,
# C:\Users\asus\AppData\Local\Temp\ipykernel_25216\2965122937.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model":    model_name,
# C:\Users\asus\AppData\Local\Temp\ipykernel_25216\2965122937.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model":    model_name,
# C:\Users\asus\AppData\Local\Temp\ipykernel_25216\2965122937.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model":    model_name,
# C:\Users\asus\AppData\Local\Temp\ipykernel_25216\2965122937.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model":    model_name,
# c:\Users\asus\anaconda3\envs\school\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\asus\AppData\Local\Temp\ipykernel_25216\2965122937.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model":    model_name,
# C:\Users\asus\AppData\Local\Temp\ipykernel_25216\2965122937.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model":    model_name,
# <style type="text/css">
# #T_070c0_row0_col2, #T_070c0_row0_col3, #T_070c0_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 0.0%, transparent 0.0%);
# }
# #T_070c0_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 0.1%, transparent 0.1%);
# }
# #T_070c0_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 0.7%, transparent 0.7%);
# }
# #T_070c0_row2_col3, #T_070c0_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 0.3%, transparent 0.3%);
# }
# #T_070c0_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 0.8%, transparent 0.8%);
# }
# #T_070c0_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 2.8%, transparent 2.8%);
# }
# #T_070c0_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 0.9%, transparent 0.9%);
# }
# #T_070c0_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 3.4%, transparent 3.4%);
# }
# #T_070c0_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 1.3%, transparent 1.3%);
# }
# #T_070c0_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 4.2%, transparent 4.2%);
# }
# #T_070c0_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 1.4%, transparent 1.4%);
# }
# </style>
# <table id="T_070c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_070c0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_070c0_level0_col1" class="col_heading level0 col1" >AC</th>
#       <th id="T_070c0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_070c0_level0_col3" class="col_heading level0 col3" >MAB</th>
#       <th id="T_070c0_level0_col4" class="col_heading level0 col4" >Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_070c0_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_070c0_row0_col0" class="data row0 col0" >Skl GBM</td>
#       <td id="T_070c0_row0_col1" class="data row0 col1" >99.562044</td>
#       <td id="T_070c0_row0_col2" class="data row0 col2" >0.013139</td>
#       <td id="T_070c0_row0_col3" class="data row0 col3" >0.007299</td>
#       <td id="T_070c0_row0_col4" class="data row0 col4" >29.417724</td>
#     </tr>
#     <tr>
#       <th id="T_070c0_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_070c0_row1_col0" class="data row1 col0" >LightGBM</td>
#       <td id="T_070c0_row1_col1" class="data row1 col1" >98.686131</td>
#       <td id="T_070c0_row1_col2" class="data row1 col2" >0.087591</td>
#       <td id="T_070c0_row1_col3" class="data row1 col3" >0.029197</td>
#       <td id="T_070c0_row1_col4" class="data row1 col4" >0.001996</td>
#     </tr>
#     <tr>
#       <th id="T_070c0_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_070c0_row2_col0" class="data row2 col0" >Random Forest</td>
#       <td id="T_070c0_row2_col1" class="data row2 col1" >86.861314</td>
#       <td id="T_070c0_row2_col2" class="data row2 col2" >0.722628</td>
#       <td id="T_070c0_row2_col3" class="data row2 col3" >0.272993</td>
#       <td id="T_070c0_row2_col4" class="data row2 col4" >3.324274</td>
#     </tr>
#     <tr>
#       <th id="T_070c0_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_070c0_row3_col0" class="data row3 col0" >Extra Trees</td>
#       <td id="T_070c0_row3_col1" class="data row3 col1" >84.817518</td>
#       <td id="T_070c0_row3_col2" class="data row3 col2" >0.816058</td>
#       <td id="T_070c0_row3_col3" class="data row3 col3" >0.305109</td>
#       <td id="T_070c0_row3_col4" class="data row3 col4" >1.483105</td>
#     </tr>
#     <tr>
#       <th id="T_070c0_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_070c0_row4_col0" class="data row4 col0" >AdaBoost</td>
#       <td id="T_070c0_row4_col1" class="data row4 col1" >67.737226</td>
#       <td id="T_070c0_row4_col2" class="data row4 col2" >2.833577</td>
#       <td id="T_070c0_row4_col3" class="data row4 col3" >0.865693</td>
#       <td id="T_070c0_row4_col4" class="data row4 col4" >1.528919</td>
#     </tr>
#     <tr>
#       <th id="T_070c0_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_070c0_row5_col0" class="data row5 col0" >Logistic_reg</td>
#       <td id="T_070c0_row5_col1" class="data row5 col1" >34.306569</td>
#       <td id="T_070c0_row5_col2" class="data row5 col2" >3.437956</td>
#       <td id="T_070c0_row5_col3" class="data row5 col3" >1.286131</td>
#       <td id="T_070c0_row5_col4" class="data row5 col4" >1.502163</td>
#     </tr>
#     <tr>
#       <th id="T_070c0_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_070c0_row6_col0" class="data row6 col0" >SVC</td>
#       <td id="T_070c0_row6_col1" class="data row6 col1" >31.678832</td>
#       <td id="T_070c0_row6_col2" class="data row6 col2" >4.160584</td>
#       <td id="T_070c0_row6_col3" class="data row6 col3" >1.439416</td>
#       <td id="T_070c0_row6_col4" class="data row6 col4" >2.045780</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = KNeighborsClassifier()

# %%
test_data = pd.read_csv("test_data.csv")

# %%
test_data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0    id   time  activityrecognition#1  \
# 0             4           4   876   77.0                  100.0
# 1             8           8   343   35.0                  100.0
# 2             9           9  4650   27.0                   69.0
# 3            11          11  4758  135.0                   23.0
# 4            13          13  1937  563.0                  100.0
#
#    android.sensor.accelerometer#mean  android.sensor.accelerometer#min  \
# 0                           9.993466                          8.965621
# 1                           9.639711                          8.996134
# 2                           9.602109                          9.014786
# 3                           9.446527                          8.901048
# 4                           9.932078                          9.608102
#
#    android.sensor.accelerometer#max  android.sensor.accelerometer#std user  \
# 0                         10.891645                          0.504117   U1
# 1                         10.027802                          0.255053   U1
# 2                         10.068528                          0.267791   U1
# 3                         10.013365                          0.317446   U1
# 4                         10.204232                          0.145972   U1
#
#    ...  android.sensor.magnetic_field_uncalibrated#max  \
# 0  ...                                       88.883841
# 1  ...                                      101.644601
# 2  ...                                      105.925670
# 3  ...                                      132.720874
# 4  ...                                      145.066006
#
#    android.sensor.orientation#mean  android.sensor.orientation#min  \
# 0                       265.698532                      230.609021
# 1                       256.222581                      233.072541
# 2                       244.539314                      223.896972
# 3                       210.199352                      189.790291
# 4                       236.313081                      216.728876
#
#    android.sensor.orientation#max  android.sensor.orientation#std  \
# 0                      305.390420                       38.592932
# 1                      282.082947                       24.707749
# 2                      267.571850                       22.009258
# 3                      232.631645                       21.907563
# 4                      256.891783                       21.622125
#
#    android.sensor.rotation_vector#mean  android.sensor.rotation_vector#min  \
# 0                             0.596241                            0.592273
# 1                             0.611548                            0.606321
# 2                             0.651163                            0.646404
# 3                             0.755494                            0.751322
# 4                             0.677672                            0.670824
#
#    android.sensor.rotation_vector#max  android.sensor.rotation_vector#std  \
# 0                            0.608622                            0.008369
# 1                            0.621611                            0.006702
# 2                            0.660189                            0.006010
# 3                            0.763951                            0.005824
# 4                            0.690845                            0.007931
#
#    target
# 0     1.0
# 1     3.0
# 2     2.0
# 3     2.0
# 4     1.0
#
# [5 rows x 45 columns]

# %%
x = test_data.drop(['user','target','Unnamed: 0.1','Unnamed: 0'], axis=1)
y = test_data['target']

# %%
# Out:
# (2470,)

# %%
best_model.fit(x,y)
pred = best_model.predict(x)

# %%
import joblib
joblib.dump(best_model, 'model_joblib')
# Out:
# ['model_joblib']
